# %% [markdown]
# <a href="https://colab.research.google.com/github/mtrianapalencia-svg/Notebooks_Agro_2026_1/blob/main/Fundamentos_2026_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1 # ENTRADA: Entra ancho y alto de la madera en metros
ancho = input("Ingresa el ancho de la ventana en metros")
ancho = float(ancho)
alto = input("Ingresa el alto de la ventana en metros")
alto = float(alto)
# PROCESO: Calcula longitud de la madera (lm) en pies y el Área del vidrio en metros cuadrados
lm = 2 * (ancho + alto) * 3.25
av = 2 * (ancho * alto)
# SALIDA: Sale la longitud ded la madera (lm) en pies
# el area del vidrio en metros cuadrados
print("Longitud de la amdera es" ,lm, "pies de longitud")
print("El área del vidrio es",av, "metros cuadrados")
# Out:
# Ingresa el ancho de la ventana en metros1
# Ingresa el alto de la ventana en metros2
# Longitud de la amdera es 19.5 pies de longitud
# El área del vidrio es 4.0 metros cuadrados
